# %%
from pressure_analysis.pressure_results_visualizer import PressureResultsVisualizer

# %%
root = r"./p_science_lotte_update"
pr_vis = PressureResultsVisualizer(root)
# Out:
# 警告: 无法从文件夹 stream_science_30_pl 解析出频率数字，跳过该文件夹。
# 警告: 无法从文件夹 stream_science_20_old 解析出频率数字，跳过该文件夹。
# 警告: 无法从文件夹 stream_science_10_old 解析出频率数字，跳过该文件夹。
# 警告: 无法从文件夹 stream_science_30_old 解析出频率数字，跳过该文件夹。

# %%
pr_vis.plot_index_update_time_stream_special(target_frequency=30, clip_percentile=1, window_size=5, use_log_scale=True)

# %%
pr_vis.plot_index_update_time_multi_freq(target_frequencies=[10, 20, 30],  window_size=10)

# %%
pr_vis.plot_performance_cdf(target_frequency=30)

# %%
pr_vis.plot_performance_cdf_multi_freq(target_frequencies=[10, 20, 30])

# %%
pr_vis.plot_qps_line_chart(target_frequency=30)

# %%
pr_vis.print_qps_average_table(target_frequencies=[10, 20, 30])
# Out:
# ...
#  Average QPS (Mean ± Std Dev) Table
# ...
# Method      FrozenPLAID  ReindexPLAID   StreamPLAID
# Frequency
# 10         24.89 ± 4.84  23.30 ± 4.25  21.37 ± 4.73
# 20         23.15 ± 4.62  23.72 ± 4.90  21.02 ± 3.76
# 30         23.42 ± 4.04  24.96 ± 4.43  20.83 ± 3.81
# ...
